# %% [markdown]
# # 5 Useful NumPy functions
#
#
# ### I have chosen the following 5 functions-
#
# Numpy stands for Numerical Python. Numpy is an open source library which is used for numerical operations with respect to linear algebra and matrices. It is created by Travis Oliphant in 2005.
#
# - function 1 = np.split()
# - function 2 = np.unique()
# - function 3 = np.transpose()
# - function 4 = np.maximum()
# - function 5 = np.sort()

# %%
# !pip install jovian --upgrade -q

# %%
import jovian

# %%
jovian.commit(project='numpy-array-operations')
# Out:
# [jovian] Attempting to save notebook..
# [jovian] Please enter your API key ( from https://jovian.ml/ ):
# API KEY: ········
# [jovian] Updating notebook "ankit114211/numpy-array-operations" on https://jovian.ml/
# [jovian] Uploading notebook..
# [jovian] Capturing environment..
# [jovian] Committed successfully! https://jovian.ml/ankit114211/numpy-array-operations
# 'https://jovian.ml/ankit114211/numpy-array-operations'

# %% [markdown]
# Let's begin by importing Numpy and listing out the functions covered in this notebook.

# %%
import numpy as np

# %%
# List of functions explained 
function1 = np.split
function2 = np.unique
function3 = np.transpose
function4 = np.full
function5 = np.sort

# %% [markdown]
# ## Function 1 - np.split()
# Split an array into multiple sub-arrays as views.

# %%
# Example 1 - working 
arr1 = np.array([1,2,3,4,5,6])
np.split(arr1,3)
# Out:
# [array([1, 2]), array([3, 4]), array([5, 6])]

# %% [markdown]
# The second argument of np.split specifies into how many subarrays we want to divide the original array.

# %%
# Example 2 - working
arr2=np.array([5,33,2,15,2,0,4,3])
np.split(arr2,2)
# Out:
# [array([ 5, 33,  2, 15]), array([2, 0, 4, 3])]

# %% [markdown]
# In the above example I divided the array into 2 subarrays. Keep in mind it doesn't effect the original array.

# %%
# Example 3 - breaking (to illustrate when it breaks)
arr3 = np.array([1,2,3,4])
np.split(arr3,3)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /srv/conda/envs/notebook/lib/python3.8/site-packages/numpy/lib/shape_base.py in split(ary, indices_or_sections, axis)
#     866     try:
# --> 867         len(indices_or_sections)
#     868     except TypeError:
#
# TypeError: object of type 'int' has no len()
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-10-bffb01b96980> in <module>
#       1 # Example 3 - breaking (to illustrate when it breaks)
#       2 arr3 = np.array([1,2,3,4])
# ----> 3 np.split(arr3,3)
#
# <__array_function__ internals> in split(*args, **kwargs)
#
# /srv/conda/envs/notebook/lib/python3.8/site-packages/numpy/lib/shape_base.py in split(ary, indices_or_sections, axis)
#     870         N = ary.shape[axis]
#     871         if N % sections:
# --> 872             raise ValueError(
#     873                 'array split does not result in an equal division')
#     874     return array_split(ary, indices_or_sections, axis)
#
# ValueError: array split does not result in an equal division

# %% [markdown]
# Snap! what happened here? Because `np.split` divides the array into two subarrays but those subarrays should contain equal no of elements. If it is not possible to divide the original array into such subarrays it will throw an error. In the above example it is not possible to divide [1,2,3,4] into 3 parts with each part containing equal number of elements "ValueError: array split does not result in an equal division"

# %% [markdown]
# This function is useful when we want to divide the array into subarrays.

# %%
jovian.commit()

# %% [markdown]
# ## Function 2 - np.unique()
#
# Returns the sorted unique elements of an array.

# %%
# Example 1 - working
arr1 = np.array([1,2,4,5,8,4,7,6])
np.unique(arr1)
# Out:
# array([1, 2, 4, 5, 6, 7, 8])

# %% [markdown]
# The function returns an array containing only the unique elements.

# %%
# Example 2 - working
arr2=np.array(['a','g','d','a','c'])
np.unique(arr2)
# Out:
# array(['a', 'c', 'd', 'g'], dtype='<U1')

# %% [markdown]
# This function is useful when we want only the unique elements in an array.

# %%
# Example 3 - breaking (to illustrate when it breaks)
a = np.array([[1, 0, 0], [1, 0, 0], [2, 3, 4]])
np.unique(a, axis=3)
# Out:
# ---------------------------------------------------------------------------
# AxisError                                 Traceback (most recent call last)
# /srv/conda/envs/notebook/lib/python3.8/site-packages/numpy/lib/arraysetops.py in unique(ar, return_index, return_inverse, return_counts, axis)
#     265     try:
# --> 266         ar = np.moveaxis(ar, axis, 0)
#     267     except np.AxisError:
#
# <__array_function__ internals> in moveaxis(*args, **kwargs)
#
# /srv/conda/envs/notebook/lib/python3.8/site-packages/numpy/core/numeric.py in moveaxis(a, source, destination)
#    1427
# -> 1428     source = normalize_axis_tuple(source, a.ndim, 'source')
#    1429     destination = normalize_axis_tuple(destination, a.ndim, 'destination')
#
# /srv/conda/envs/notebook/lib/python3.8/site-packages/numpy/core/numeric.py in normalize_axis_tuple(axis, ndim, argname, allow_duplicate)
#    1357     # Going via an iterator directly is slower than via list comprehension.
# -> 1358     axis = tuple([normalize_axis_index(ax, ndim, argname) for ax in axis])
#    1359     if not allow_duplicate and len(set(axis)) != len(axis):
#
# /srv/conda/envs/notebook/lib/python3.8/site-packages/numpy/core/numeric.py in <listcomp>(.0)
#    1357     # Going via an iterator directly is slower than via list comprehension.
# -> 1358     axis = tuple([normalize_axis_index(ax, ndim, argname) for ax in axis])
#    1359     if not allow_duplicate and len(set(axis)) != len(axis):
#
# AxisError: source: axis 3 is out of bounds for array of dimension 2
#
# During handling of the above exception, another exception occurred:
#
# AxisError                                 Traceback (most recent call last)
# <ipython-input-18-bd2897b4d587> in <module>
#       1 # Example 3 - breaking (to illustrate when it breaks)
#       2 a = np.array([[1, 0, 0], [1, 0, 0], [2, 3, 4]])
# ----> 3 np.unique(a, axis=3)
#
# <__array_function__ internals> in unique(*args, **kwargs)
#
# /srv/conda/envs/notebook/lib/python3.8/site-packages/numpy/lib/arraysetops.py in unique(ar, return_index, return_inverse, return_counts, axis)
#     267     except np.AxisError:
#     268         # this removes the "axis1" or "axis2" prefix from the error message
# --> 269         raise np.AxisError(axis, ar.ndim)
#     270
#     271     # Must reshape to a contiguous 2D array for this to work...
#
# AxisError: axis 3 is out of bounds for array of dimension 2

# %% [markdown]
# Since it is an 2-D array, the axis 3 is out of range.

# %% [markdown]
# This np.unique() fucntion can be used to get the unique values in an array.

# %%
jovian.commit()
# Out:
# [jovian] Attempting to save notebook..
# [jovian] Updating notebook "ankit114211/numpy-array-operations" on https://jovian.ml/
# [jovian] Uploading notebook..
# [jovian] Capturing environment..
# [jovian] Committed successfully! https://jovian.ml/ankit114211/numpy-array-operations
# 'https://jovian.ml/ankit114211/numpy-array-operations'

# %% [markdown]
# ## Function 3 - np.transpose()
#
# For an array a with two axes, transpose(a) gives the matrix transpose.

# %%
# Example 1 - working
a=np.array([
    [1,2],
    [3,4]
])
np.transpose(a)
# Out:
# array([[1, 3],
#        [2, 4]])

# %% [markdown]
# Simple matrix transpose

# %%
# Example 2 - working
a2=np.array([1,2,3])
np.transpose(a2)
# Out:
# array([1, 2, 3])

# %% [markdown]
# Transposing a 1-D array returns an unchanged view of the original array.

# %% [markdown]
# Use this function to calculate the transpose of a matrix.

# %%
jovian.commit()
# Out:
# [jovian] Attempting to save notebook..
# [jovian] Updating notebook "ankit114211/numpy-array-operations" on https://jovian.ml/
# [jovian] Uploading notebook..
# [jovian] Capturing environment..
# [jovian] Committed successfully! https://jovian.ml/ankit114211/numpy-array-operations
# 'https://jovian.ml/ankit114211/numpy-array-operations'

# %% [markdown]
# ## Function 4 - np.maximum
#
# Compares two arrays and pulls the maximum value in each.

# %%
# Example 1 - working
ar1 = np.array([[74, 52, 44, 87], 
                 [19, 22, 95, 50], 
                 [16, 13, 7, 40]])

ar2 = np.array([[14, 66, 27, 74], 
                 [92, 2, 56, 49], 
                 [3, 11, 17, 99]])

np.maximum(ar1, ar2)
# Out:
# array([[74, 66, 44, 87],
#        [92, 22, 95, 50],
#        [16, 13, 17, 99]])

# %% [markdown]
# Compares two arrays of numbers, and brings back the highest numer in each creating one array with the highest ones.

# %%
# Example 2 - working
ar3 = np.array([[.24, .3, -.14, .67], 
                 [.87, .26, -.35, .21], 
                 [0, -.87, .36, .44]])

ar4 = np.array([[.21, .67, -.31, -.74], 
                 [.99, .52, -.56, .47], 
                 [-.87, -.23, .11, .5]])

np.maximum(ar3, ar4)
# Out:
# array([[ 0.24,  0.67, -0.14,  0.67],
#        [ 0.99,  0.52, -0.35,  0.47],
#        [ 0.  , -0.23,  0.36,  0.5 ]])

# %% [markdown]
# using decimals and negative numbers, pulls largest numbers again out of the pairs in the arrays.

# %%
# Example 3 - breaking (to illustrate when it breaks)
ar5 = np.array([["JOE", 52, 44, 87], 
                 [19, 22, 95, 50], 
                 [16, 13, 7, 40]])

ar6 = np.array([[14, 66, 27, 74], 
                 [92, 2, 56, 49], 
                 [3, 11, 17, 99]])

np.maximum(ar5, ar6)
# Out:
# ---------------------------------------------------------------------------
# UFuncTypeError                            Traceback (most recent call last)
# <ipython-input-6-2fb525a0e67b> in <module>
#       8                  [3, 11, 17, 99]])
#       9
# ---> 10 np.maximum(ar5, ar6)
#
# UFuncTypeError: ufunc 'maximum' did not contain a loop with signature matching types (dtype('<U21'), dtype('<U21')) -> dtype('<U21')

# %% [markdown]
# "Joe" is not a number and cannot be calculated with np.maximum. Everything else stops with the error.

# %%
jovian.commit()
# Out:
# [jovian] Attempting to save notebook..
# [jovian] Updating notebook "ankit114211/numpy-array-operations" on https://jovian.ml/
# [jovian] Uploading notebook..
# [jovian] Capturing environment..
# [jovian] Committed successfully! https://jovian.ml/ankit114211/numpy-array-operations
# 'https://jovian.ml/ankit114211/numpy-array-operations'

# %% [markdown]
# ## Function 5 - np.sort()
#
# Sorting means putting something in a sequence. Numpy comes with an inbuilt library which will allows us to sort an arrray in ascending order and retrurn us a copy of sorted array without modifying the actual instance.

# %%
# Example 1 - working
arr = np.array([[7,1],[5,9],[8,3]])
print('Along with the last axis :')
print(np.sort(arr))
print('Along with the first axis :')
print(np.sort(arr,axis=0))
# Out:
# Along with the last axis :
# [[1 7]
#  [5 9]
#  [3 8]]
# Along with the first axis :
# [[5 1]
#  [7 3]
#  [8 9]]

# %% [markdown]
# In this example the print statement will return the sorted version of an array (arr) along with the default axis and along with the first axis.

# %%
# Example 2 - working
arr = np.array(['banana', 'cherry', 'apple','Mango'])
print('Ascending order :')
print(np.sort(arr))
# Out:
# Ascending order :
# ['Mango' 'apple' 'banana' 'cherry']

# %% [markdown]
# In this example we are sorting an array alphabatically. Here it captures the binary value of the first element to sort so you can see in the above example 'Mango' is the first element to be sorted.

# %%
# Example 3 - breaking (to illustrate when it breaks)
arr = np.array([[7,1],[5,9],[8,3]])
print(np.sort(arr,axis=2))
# Out:
# ---------------------------------------------------------------------------
# AxisError                                 Traceback (most recent call last)
# <ipython-input-13-4b51b05553b4> in <module>
#       1 # Example 3 - breaking (to illustrate when it breaks)
#       2 arr = np.array([[7,1],[5,9],[8,3]])
# ----> 3 print(np.sort(arr,axis=2))
#
# <__array_function__ internals> in sort(*args, **kwargs)
#
# /srv/conda/envs/notebook/lib/python3.8/site-packages/numpy/core/fromnumeric.py in sort(a, axis, kind, order)
#     989     else:
#     990         a = asanyarray(a).copy(order="K")
# --> 991     a.sort(axis=axis, kind=kind, order=order)
#     992     return a
#     993
#
# AxisError: axis 2 is out of bounds for array of dimension 2

# %% [markdown]
# In this example we have specified the wrong axis so it breaks It can be fixed by either continuing with default axis or giving the axis as 0 or 1.

# %%
jovian.commit()
# Out:
# [jovian] Attempting to save notebook..
# [jovian] Updating notebook "ankit114211/numpy-array-operations" on https://jovian.ml/
# [jovian] Uploading notebook..
# [jovian] Capturing environment..
# [jovian] Committed successfully! https://jovian.ml/ankit114211/numpy-array-operations
# 'https://jovian.ml/ankit114211/numpy-array-operations'

# %% [markdown]
# ## Conclusion
#
# In this notebook you will find 5 useful numpy functions and 3 refrenced examples of every function. Out of the 3 one example will also convey you when the function is going to break so keep that condition in your mind while using those functions.

# %% [markdown]
# ## Reference Links
# Provide links to your references and other interesting articles about Numpy arrays:
# * Numpy official tutorial : https://numpy.org/doc/stable/user/quickstart.html
# * Used GeeksforGeeks for some extra refrence :https://www.geeksforgeeks.org/

# %%
jovian.commit()
# Out:
# [jovian] Attempting to save notebook..
# [jovian] Updating notebook "ankit114211/numpy-array-operations" on https://jovian.ml/
# [jovian] Uploading notebook..
# [jovian] Capturing environment..
# [jovian] Committed successfully! https://jovian.ml/ankit114211/numpy-array-operations
# 'https://jovian.ml/ankit114211/numpy-array-operations'
